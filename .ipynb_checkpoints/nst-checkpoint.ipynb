# %%
import keras
from keras.preprocessing.image import load_img, img_to_array
from keras import backend as K
from keras.applications import vgg19
import tensorflow as tf
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Load images and reshape them

# %%
content_img = load_img("chicago.jpg")
plt.imshow(content_img)

# %%
style_img = load_img("great_wave_of_kanagawa.jpg")
plt.imshow(style_img)

# %%
width , height = content_img.size
print("Height: " , height)
print("Width: " , width)
# Out:
# Height:  474
# Width:  712

# %%
#Resize and ration
img_height = 400
img_width = int(width * img_height / height)
print("Desired Height: " , img_height)
print("Desired Width: " , img_width)
# Out:
# Desired Height:  400
# Desired Width:  600

# %% [markdown]
# ## Calculate the three costs

# %%
def content_loss(base , generated):
    return K.sum(K.square(generated - base))

# %%
def total_variation_loss(x):
    a = K.square(x[:, :img_height - 1, :img_width - 1, :] - x[:, 1:, :img_width - 1, :])
    b = K.square(x[:, :img_height - 1, :img_width - 1, :] - x[:, :img_height - 1, 1:, :])
    return K.sum(a+b)

# %%
def gram_matrix(x):
    features = K.batch_flatten(K.permute_dimensions(x, (2, 0, 1)))
    gram = K.dot(features, K.transpose(features))
    return gram

# %%
def style_loss(style, combination):
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    size = img_height * img_width
    return K.sum(K.square(S - C)) / (4. * (channels ** 2) * (size ** 2))

# %% [markdown]
# ## Preprocess and deprocess image

# %%
def preprocess_image(image_path):
    img = load_img(image_path, target_size=(img_height, img_width))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg19.preprocess_input(img)
    return img

# %%
def deprocess_image(x):
    x.reshape((img_height, img_width, 3))
    x[:, :, 0] += 103.939
    x[:, :, 1] += 116.779
    x[:, :, 2] += 123.68
    x = x[:, :, ::-1]
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %% [markdown]
# ## Declare constants and placeholders

# %%
content_image = K.constant(preprocess_image("chicago.jpg"))
style_image = K.constant(preprocess_image("great_wave_of_kanagawa.jpg"))

# %%
generated_image = combination_image = K.placeholder((1, img_height, img_width, 3))

# %%
input_list = K.concatenate([content_image , style_image , generated_image] , axis = 0)

# %% [markdown]
# ## Create VGG-19 Model

# %%
model = vgg19.VGG19(input_tensor=input_list, weights='imagenet', include_top=False)
print(model)
# Out:
# WARNING:tensorflow:From /home/nick_nack/.local/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /home/nick_nack/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# <keras.engine.training.Model object at 0x7f73446e5e10>

# %% [markdown]
# ## Display layers in the model

# %%
model.layers
# Out:
# [<keras.engine.input_layer.InputLayer at 0x7f73447cf860>,
#  <keras.layers.convolutional.Conv2D at 0x7f73447d7198>,
#  <keras.layers.convolutional.Conv2D at 0x7f73447d7470>,
#  <keras.layers.pooling.MaxPooling2D at 0x7f73447a27b8>,
#  <keras.layers.convolutional.Conv2D at 0x7f734473ad68>,
#  <keras.layers.convolutional.Conv2D at 0x7f7344741908>,
#  <keras.layers.pooling.MaxPooling2D at 0x7f7344747b38>,
#  <keras.layers.convolutional.Conv2D at 0x7f7344750b00>,
#  <keras.layers.convolutional.Conv2D at 0x7f73447566d8>,
#  <keras.layers.convolutional.Conv2D at 0x7f734475e908>,
#  <keras.layers.convolutional.Conv2D at 0x7f734476a668>,
#  <keras.layers.pooling.MaxPooling2D at 0x7f73446f94e0>,
#  <keras.layers.convolutional.Conv2D at 0x7f73446ff278>,
#  <keras.layers.convolutional.Conv2D at 0x7f7344706ef0>,
#  <keras.layers.convolutional.Conv2D at 0x7f73447141d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f7344718ac8>,
#  <keras.layers.pooling.MaxPooling2D at 0x7f7344727198>,
#  <keras.layers.convolutional.Conv2D at 0x7f73446b3ba8>,
#  <keras.layers.convolutional.Conv2D at 0x7f73446bb780>,
#  <keras.layers.convolutional.Conv2D at 0x7f73446c29b0>,
#  <keras.layers.convolutional.Conv2D at 0x7f73446cf710>,
#  <keras.layers.pooling.MaxPooling2D at 0x7f73446d9470>]

# %%
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])

# %% [markdown]
# ## Select content and Style activations

# %%
content_layer = 'block5_conv2'

# %%
style_layers = ['block1_conv1','block2_conv1','block3_conv1','block4_conv1','block5_conv1']

# %% [markdown]
# ## Select the hyperparameters (depends on the aspect ratio goal)

# %%
total_variational_weight = 0.0001
style_weight             = 1.
content_weight           = 0.25

# %% [markdown]
# ## Implement Calculations of cost

# %%
total_loss = K.variable(0.0)

# %%
activation1 = outputs_dict[content_layer]
content_activation1 = activation1[0,:,:,:]
generated_activation1 = activation1[2,:,:,:]
total_loss = total_loss + (content_weight * content_loss(content_activation1 , generated_activation1))

# %%
for layer in style_layers:
    activation2 = outputs_dict[layer]
    style_activation2 = activation2[1,:,:,:]
    generated_activation2 = activation2[2,:,:,:]
    total_loss = total_loss + (style_weight * style_loss(style_activation2 , generated_activation2))

# %%
total_loss = total_loss + (total_variational_weight * total_variation_loss(generated_image))

# %% [markdown]
# ## Create loss and gradient access function

# %%
grads = K.gradients(total_loss, generated_image)
fetch_loss_and_grads = K.function([generated_image], [total_loss, grads])

# %%
def loss(x):
    x = x.reshape((1, img_height, img_width, 3))
    outs = fetch_loss_and_grads([x])
    loss_value = outs[0]
    return loss_value

# %%
def grads(x):
    x = x.reshape((1, img_height, img_width, 3))
    outs = fetch_loss_and_grads([x])
    grad_values = outs[1].flatten().astype('float64')
    return grade_values
